# %%
 list=["apple","banana","cherry"]
print(list)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list=["apple","banana","cherry"]
print(list[1])
# Out:
# banana

# %%
list=["apple","banana","cherry"]
print(list[0:1])
# Out:
# ['apple']

# %%
list=["apple","banana","cherry"]
list[1]="blackcurrant"
print(list)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
list=["apple","banana","cherry"]
list.append("blackcurrant")
print(list)
# Out:
# ['apple', 'banana', 'cherry', 'blackcurrant']

# %%
list=["apple","banana","cherry"]
list.remove("banana")
print(list)
# Out:
# ['apple', 'cherry']

# %%
tuple=("orange","kiwi","banana")
print(tuple)
# Out:
# ('orange', 'kiwi', 'banana')

# %%
tuple=("orange","kiwi","banana")
print(tuple[1])
# Out:
# kiwi

# %%
tuple1=("apple","banana","cheery")
tuple2=("orange","kiwi","watermelon")
tuple3=tuple1+tuple2
print(tuple3)
# Out:
# ('apple', 'banana', 'cheery', 'orange', 'kiwi', 'watermelon')

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":"1965"
}
print(thisdict)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': '1965'}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":"1965"
}
x = thisdict["model"]
print(x)
# Out:
# mustang

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":"1965"
}
thisdict["year"]=2018
print(thisdict)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 2018}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":"1965"
}
thisdict["colour"]="red"
print(thisdict)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': '1965', 'colour': 'red'}

# %%
thisdict={
    "brand":"ford",
    "model":"mustang",
    "year":"1965"
}
del thisdict ["model"]
print(thisdict)
# Out:
# {'brand': 'ford', 'year': '1965'}
